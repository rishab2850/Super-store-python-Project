# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
a = pd.read_csv("/Users/rishabverma/Downloads/archive.csv")

# %%
a
# Out:
#         Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0        18606  Not Specified      0.01        2.88           0.50
# 1        20847           High      0.01        2.84           0.93
# 2        23086  Not Specified      0.03        6.68           6.15
# 3        23087  Not Specified      0.01        5.68           3.60
# 4        23088  Not Specified      0.00      205.99           2.50
# ...        ...            ...       ...         ...            ...
# 11061   Region        Manager       NaN         NaN            NaN
# 11062  Central          Chris       NaN         NaN            NaN
# 11063     East           Erin       NaN         NaN            NaN
# 11064    South            Sam       NaN         NaN            NaN
# 11065     West        William       NaN         NaN            NaN
#
#        Customer ID    Customer Name    Ship Mode Customer Segment  \
# 0              2.0  Janice Fletcher  Regular Air        Corporate
# ...

# %%
a.shape
# Out:
# (11066, 24)

# %% [markdown]
# #Finding missing value in all

# %%
a.isnull().sum()
# Out:
# Row ID                     0
# Order Priority             0
# Discount                1640
# Unit Price              1640
# Shipping Cost           1640
# Customer ID             1640
# Customer Name           1640
# Ship Mode               1640
# Customer Segment        1640
# Product Category        1640
# Product Sub-Category    1640
# Product Container       1640
# Product Name            1640
# Product Base Margin     1712
# Region                  1640
# State or Province       1640
# City                    1640
# Postal Code             1640
# Order Date              1640
# Ship Date               1640
# Profit                  1640
# Quantity ordered new    1640
# Sales                   1640
# Order ID                1640
# dtype: int64

# %% [markdown]
# #fill null value in productbasemargin

# %%
a.isnull().sum()
# Out:
# Row ID                     0
# Order Priority             0
# Discount                1640
# Unit Price              1640
# Shipping Cost           1640
# Customer ID             1640
# Customer Name           1640
# Ship Mode               1640
# Customer Segment        1640
# Product Category        1640
# Product Sub-Category    1640
# Product Container       1640
# Product Name            1640
# Product Base Margin     1712
# Region                  1640
# State or Province       1640
# City                    1640
# Postal Code             1640
# Order Date              1640
# Ship Date               1640
# Profit                  1640
# Quantity ordered new    1640
# Sales                   1640
# Order ID                1640
# dtype: int64

# %% [markdown]
# #How much people have high priority order

# %%
a['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Returned         1634
# Critical            1
# Status              1
# Manager             1
# Chris               1
# Erin                1
# Sam                 1
# William             1
# Name: count, dtype: int64

# %% [markdown]
# #there is 2 critical values so we can solve them

# %%
a['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical ',
#        'Status', 'Returned', 'Manager', 'Chris', 'Erin', 'Sam', 'William'],
#       dtype=object)

# %%
a['Order Priority'] = a['Order Priority'].replace("Critical ", "Critical")

# %% [markdown]
# #Make the graph of this

# %%
plt.figure(figsize = (11,4))
sns.countplot(x = "Order Priority", data = a)
plt.title("Number of Order Priority")
plt.savefig("Number of Order Priority.jpg")
plt.show()

# %%
 a.head(1)
# Out:
#   Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0  18606  Not Specified      0.01        2.88            0.5          2.0
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
#
#     Region State or Province     City  Postal Code  Order Date   Ship Date  \
# 0  Central          Illinois  Addison      60101.0  05/28/2012  05/30/2012
#
#   Profit  Quantity ordered new Sales Order ID
# 0   1.32                   2.0   5.9  88525.0
#
# [1 rows x 24 columns]

# %% [markdown]
# #How much maximum orders are in which ship mode

# %%
 a['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %% [markdown]
# #Making graph od ship modes

# %%
 x = a['Ship Mode'].value_counts().index
 y = a['Ship Mode'].value_counts().values

# %%
x
# Out:
# Index(['Regular Air', 'Delivery Truck', 'Express Air'], dtype='object', name='Ship Mode')

# %%
y
# Out:
# array([7036, 1283, 1107])

# %%
plt.pie(y, labels = x, startangle = 50, autopct = "%0.2f%%")
plt.title("Shipping modes")
plt.savefig("Shipping Modes.jpg")
plt.legend(loc = 2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # sales by product category

# %%
sns.countplot( x = "Ship Mode", data = a , hue = "Product Category")
plt.title("Sales By Product Category")
plt.savefig("Sales By Product category.jpg")
plt.show()

# %% [markdown]
# #Customer segment Base

# %%
sns.countplot( x = "Customer Segment" , data = a, )
plt.title("Customer Segment Base")
plt.savefig("Customer Segment base.jpg")
plt.show()

# %%
sns.countplot( x = "Product Category" , data = a, )
plt.title("Product Category")
plt.savefig("Product Category.jpg")
plt.show()

# %%
sns.countplot( x = "Product Category" , data = a, hue = "Region" )
plt.title("Product Category By Region")
plt.savefig("Product category By Region.jpg")
plt.show()
